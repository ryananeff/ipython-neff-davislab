# %% [markdown]
# ## Python-scarecrow test code (working copy)

# %%
# Imports / style (run this first always)

# %matplotlib inline
from collections import defaultdict
import json
import sys
import time

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib import rcParams
import matplotlib.cm as cm
import matplotlib as mpl

class AwesomeError(Exception):
     def __init__(self, value):
         self.value = value
         pass
     def __str__(self):
         return repr(self.value)
         pass

#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'


def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()
        
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

import Bio as bp
from Bio.Sequencing.Applications import BwaAlignCommandline as bwa_aln
from Bio.Sequencing.Applications import BwaSamseCommandline as bwa_samse
from Bio.Sequencing.Applications import BwaSampeCommandline as bwa_sampe
from Bio.Sequencing.Applications import BwaIndexCommandline as bwa_index
from Bio.Sequencing.Applications import BwaBwaswCommandline as bwa_bwasw
import HTSeq as ht
import subprocess

# %%
#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'


def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()
        
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

# %%
from multiprocessing import Process, Manager

def f(d):
    d[1] += '1'
    d['2'] += 2

if __name__ == '__main__':
    manager = Manager()

    d = manager.dict()
    d[1] = '1'
    d['2'] = 2

    p1 = Process(target=f, args=(d,))
    p2 = Process(target=f, args=(d,))
    p1.start()
    p2.start()
    p1.join()
    p2.join()

    print d
# Out:
# {1: '111', '2': 6}

# %%
set_cells = set()

# %%
set_cells = set([783, 1086, 1425, 1416, 1323, 1416, 351, 1108, 995, 1425, 155, 390, 1086, 783, 351, 668, 1105, 472, 668, 1105, 1416, 351, 1060, 1108, 155, 1507, 1323, 1449, 1507, 995, 1425, 783])

# %%
len(set_cells)
# Out:
# 16

# %%
'''
scarecrow

Usage:
    Make alternate reference sequences

Inputs:
    seq
        A filename to the fastq sequence that the alternate genome should be made from
    ref
        the consensus sequence that should be used
    prior_snp
        (optional) SNP priors
    prior_sv
        (optional) structural variation priors
    prior_con
        (optional) prior consensus sequence

Returns:
    new_ref
        a tuple containing the .fa alternate consensus file and its index
    applied_variants
        a DataFrame containing the applied changes between the current reference and the new one
    liftover
        a chain file to convert between the two references
    error_log
        text containing errors and debugging information

'''

import Bio as bp
from Bio.Sequencing.Applications import BwaAlignCommandline as bwa_aln
from Bio.Sequencing.Applications import BwaSamseCommandline as bwa_samse
from Bio.Sequencing.Applications import BwaSampeCommandline as bwa_sampe
from Bio.Sequencing.Applications import BwaIndexCommandline as bwa_index
from Bio.Sequencing.Applications import BwaBwaswCommandline as bwa_bwasw
import HTSeq

seq1 = '/media/ryan/RyanNeffBioinformatics/phenom/Data/raw_seq/SRR350098_1.filt.fastq'
seq2 = '/media/ryan/RyanNeffBioinformatics/phenom/Data/raw_seq/SRR350098_2.filt.fastq'
ref = '/media/ryan/RyanNeffBioinformatics/phenom/Data/references/hg19.fa'

def scarecrow(seq1='', seq2='', ref='',prior_snp='', prior_sv='', prior_con=''):
    # step 1 - align the sequence data to the reference provided
    sai_file1='bwa_aln_1.sai'
    sai_file2='bwa_aln_2.sai'
    bwa_cmd = bwa_aln(reference=ref, read_file=seq1, R=100, q=10, t=8)
    bwa_cmd(sai_file1)
    bwa_cmd = bwa_aln(reference=ref, read_file=seq2, R=100, q=10, t=8)
    bwa_cmd(sai_file2)
    bwa_cmd = bwa_sampe(sai_file1=sai_file2, sai_file2=sai_file2,
                        read_file1=seq1, read_file2=seq2)
    
    # step 2 - variant calling
    # step 3 - SV calling
    # step 4 - CNV calling
    # step 5 - de novo alignment of unmapped reads
    # step 6 - attempt to place new unmapped contigs generated in step 5 onto the genome
    # step 7 - filter ALL changes to genome somehow (50% for now)
    # step 8 - make alternate reference
    # step 9 - (?) Realignment to alternate sequence (cross-validation?)
    # step 10 - format for return
    return new_ref, applied_variants, liftover, error_log

# %%
bwa_cmd = bwa_aln(reference=ref, read_file=seq1, R=100)
print(bwa_cmd)
# Out:
# bwa aln /media/ryan/RyanNeffBioinformatics/phenom/Data/references/hg19.fa /media/ryan/RyanNeffBioinformatics/phenom/Data/raw_seq/SRR350098_1.filt.fastq -R 100
