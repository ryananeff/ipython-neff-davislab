# %%
# %run ipy_setup.py
# %matplotlib inline
rcParams['figure.figsize'] = (50, 50)
rcParams['patch.edgecolor'] = 'blue'
rcParams['figure.dpi'] = 300
rcParams['font.size'] = 10
rcParams['font.family'] = 'sans-serif'

# %%
data = pd.read_csv('kinship_no_labels.txt', sep='\t', header=None)

# %%
cols = pd.read_csv('kinship_cols.txt', sep='\t', header=None)
rows = pd.read_csv('kinship_rows.txt', sep='\t', header=None)

# %%
list([i[1] for i in [a.split("_") for a in rows[0]]])
# Out:
# ['100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '10',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '11',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '12',
#  '130',
#  '131',
#  '132',
#  '133',
#  '134',
#  '135',
#  '136',
#  '137',
#  '138',
#  '139',
#  '13',
#  '140',
#  '141',
#  '142',
#  '143',
#  '144',
#  '145',
#  '146',
#  '147',
#  '148',
#  '149',
#  '14',
#  '150',
#  '151',
#  '152',
#  '153',
#  '154',
#  '155',
#  '156',
#  '157',
#  '158',
#  '159',
#  '15',
#  '160',
#  '161',
#  '162',
#  '163',
#  '164',
#  '165',
#  '166',
#  '167',
#  '168',
#  '169',
#  '16',
#  '170',
#  '171',
#  '172',
#  '173',
#  '174',
#  '175',
#  '176',
#  '177',
#  '178',
#  '179',
#  '17',
#  '180',
#  '181',
#  '182',
#  '183',
#  '184',
#  '185',
#  '186',
#  '187',
#  '188',
#  '189',
#  '18',
#  '190',
# ...

# %%
fig, ax = plt.subplots()
heatmap = ax.pcolor(data, cmap=plt.cm.Blues)

# put the major ticks at the middle of each cell
ax.set_xticks(np.arange(data.shape[0])+0.5, minor=False)
ax.set_yticks(np.arange(data.shape[1])+0.5, minor=False)

# want a more natural, table-like display
ax.invert_yaxis()
ax.xaxis.tick_top()

ax.set_xticklabels(list([i[1] for i in [a.split("_") for a in rows[0]]]), minor=False)
ax.set_yticklabels(list([i[1] for i in [a.split("_") for a in cols[0]]]), minor=False)

plt.xticks(rotation=90)

plt.show()

# %%
waldscores = pd.read_csv('/data/test/home/neffra/mhgrid_complete_vcfs_351_old_seqwright/singlevarassoc_seqw.out.SingleScore.assoc', sep='\t')

# %%
waldscores
# Out:
#    CHROM     POS REF ALT  N_INFORMATIVE        AF      STAT DIRECTION    PVALUE
# 0   chr1   65898   T   C            331  0.014563  0.000175         -  0.989444
# 1   chr1   69496   G   A            331  0.002000  0.802857         -  0.370241
# 2   chr1   69511   A   G            331  0.608000  2.656940         +  0.103099
# 3   chr1   69555   T   A            331  0.003968  0.818868         -  0.365511
# 4   chr1  721428   G   A            331  0.001511  1.270960         +  0.259586
# 5   chr1  721450   G   A            331  0.016616  0.008359         +  0.927153
# 6   chr1  721705   A   G            331  0.051360  0.124028         -  0.724706
# 7   chr1  721735   T   A            331  0.001511  1.270960         +  0.259586
# 8   chr1  721753   A   G            331  0.001515  1.264900         +  0.260725
# 9   chr1  721757   T   A            331  0.019817  0.181274         -  0.670280
# 10  chr1  721891   G   A            331  0.000000  0.000000         -  1.000000
# ...

# %%
waldscores = waldscores.sort(columns='PVALUE', ascending=True)
len(waldscores)
# Out:
# 547538

# %%
sigvariants = waldscores[waldscores['PVALUE'] <= 0.000000091] # this represents 0.05/547538, bonferroni statistic

# %%
sigvariants.to_csv('/data/test/home/neffra/mhgrid_complete_vcfs_351_old_seqwright/waldscores_sig.txt', sep='\t', index=None)
